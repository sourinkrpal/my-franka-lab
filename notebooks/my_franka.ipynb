# %% [markdown]
# # Franka Demo (Basic)
# ## By Sourin

# %% [markdown]
# #### Before running the simulation in **Cell 2**, please ensure that your Desktop VNC is running

# %%
from utils import display_desktop
display_desktop()

# %% [markdown]
# ### Run Franka MuJoCo Demo

# %% [markdown]
# #### Execute the cell below to launch the interactive simulation (Start / Stop buttons will appear)

# %%
from franka_mujoco_demo import start_demo
start_demo()
